# %% [markdown]
# ## Loading Dataset, Installing dependencies, Performing Sentiment Analysis

# %%
# Import PyDrive and associated libraries
# This only needs to be done once per notebook
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client
# This only needs to be done once per notebook
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Download a file based on its file ID.

# A file ID looks like: laggVyWshwcyP6kEI-y_W3P8D26sz
file_id = '13U0iA49UMjjSTPrVMkkamqtU9Q2qepUO' # Check your own ID in GDrive
downloaded = drive.CreateFile({'id': file_id})

# Save file in Colab memory
downloaded.GetContentFile('tweet_data.csv')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
import seaborn as sns
sns.set_style('dark')
from wordcloud import WordCloud
from textblob import TextBlob

# %%
df = pd.read_csv('tweet_data.csv', lineterminator='\n')
df = df.drop(['Unnamed: 0'],axis=1)

# %%
# Performing VADER Sentiment Analysis
import nltk
nltk.download('vader_lexicon') # Download the VADER lexicon
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Initialize sentiment intensity analyzer
sia = SentimentIntensityAnalyzer()

# Obtaining NLTK scores
df['VScore'] = df['Clean Text'].apply(lambda x: sia.polarity_scores(x))

# Obtaining NLTK compound score
df['VComp'] = df['VScore'].apply(lambda score_dict: score_dict['compound'])

# Set threshold to define neutral sentiment
neutral_thresh = 0.05

# Categorize scores into the sentiments of positive, neutral or negative
df['Sentiment'] = df['VComp'].apply(lambda c: 'Positive' if c >= neutral_thresh else ('Negative' if c <= -(neutral_thresh) else 'Neutral'))
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# /usr/local/lib/python3.7/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %% [markdown]
# # Ngrams Analysis

# %%
import networkx as nx
import itertools, collections
from nltk import bigrams
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
new_stopwords_to_add = ['covid19', 'covid','vaccine', 'covid-19', '19', 'vaccines', 'vaccine.','vaccine?', '-', '.']
stop_words.extend(new_stopwords_to_add)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Check d[0].items() for understanding more about graph plot

def BigramsAnalysis(sentiment):
  l_words = df[df["Sentiment"]==sentiment]["Clean Text"].tolist()
  words_in_tweet = [tweet.split() for tweet in l_words]
  words_lemmatized = [[word for word in tweet_words]
              for tweet_words in words_in_tweet]
  tweets_nsw = [[word for word in tweet_words if not word in stop_words]
              for tweet_words in words_lemmatized]
  terms_bigram = [list(bigrams(tweet)) for tweet in tweets_nsw if tweet]
  bigrams_list = list(itertools.chain(*terms_bigram))
  bigram_counts = collections.Counter(bigrams_list)
  bigram_df = pd.DataFrame(bigram_counts.most_common(50),
                             columns=['bigram', 'count'])
  d = bigram_df.set_index('bigram').T.to_dict('records')
  G = nx.Graph()
  for k, v in d[0].items():
    G.add_edge(k[0], k[1], weight=(v))
  fig, ax = plt.subplots(figsize=(14, 10))

  pos = nx.spring_layout(G, k=2)

  # Plot networks
  nx.draw_networkx(G, pos,
                  font_size=16,
                  width=3,
                  edge_color='grey',
                  node_color='purple',
                  with_labels = False,
                  ax=ax)

  # Create offset labels
  for key, value in pos.items():
      x, y = value[0]+.100, value[1]+.025
      ax.text(x, y,
              s=key,
              bbox=dict(facecolor='red', alpha=0.15),
              horizontalalignment='center', fontsize=13)
      
  plt.show()
  return bigram_df

def Search(keywords):
  pd.set_option('display.max_colwidth', 400)
  result = df[df["Clean Text"].str.contains(keywords)]["Text"]
  return result

# %% [markdown]
# # Testing Analysis on data

# %%
input_ = 'Negative'
neg = BigramsAnalysis(input_)

# %%
neg
# Out:
#                      bigram  count
# 0          (emergency, use)   7756
# 1           (side, effects)   6972
# 2     (allergic, reactions)   5082
# 3      (allergic, reaction)   3578
# 4             (new, strain)   3241
# 5     (healthcare, workers)   2949
# 6              (long, term)   2796
# 7      (use, authorization)   2794
# 8               (flu, shot)   2390
# 9              (wear, mask)   2335
# 10                (let, us)   2306
# 11            (front, line)   2251
# 12       (severe, allergic)   1932
# 13            (people, get)   1931
# 14             (cut, price)   1828
# 15      (income, countries)   1811
# 16       (countless, lives)   1764
# 17         (rake, billions)   1763
# 18          (lower, income)   1762
# 19    (billions, expensive)   1759
# 20           (refuses, cut)   1758
# 21     (expensive, refuses)   1754
# 22           (price, lower)   1754
# 23     (costing, countless)   1752
# 24     (countries, costing)   1750
# 25            (first, line)   1715
# 26           (people, died)   1698
# 27           (white, house)   1677
# 28         (herd, immunity)   1640
# 29     (pfizers, emergency)   1631
# 30           (many, people)   1628
# 31           (health, care)   1628
# 32   (conspiracy, theories)   1601
# 33              (line, get)   1598
# 34               (I, would)   1544
# 35             (get, first)   1505
# 36        (get, vaccinated)   1424
# 37         (public, health)   1402
# 38            (people, die)   1396
# 39             (high, risk)   1354
# 40               (I, going)   1294
# 41        (pfizer, moderna)   1273
# 42            (warp, speed)   1271
# 43            (every, year)   1264
# 44               (get, flu)   1237
# 45      (panel, recommends)   1231
# 46             (next, week)   1224
# 47            (wear, masks)   1202
# 48  (trump, administration)   1191
# 49          (wearing, mask)   1173

# %%
Search("high risk")
# Out:
# 101        @thegreylady4 @gill_godwin @SeamusORegan @PattyHajdu @Scott_Simms @ChurenceRogers @McDonald4Avalon @Gudie . i am not 'trolling' anything . i, like so many other Canadians,  am high risk . completely appropriate to demand access to covid vaccine without any unnecessary delay . pointing to Health Canada's history of delay for the sake of delay is entirely called for .
# 630                                                                                                                                   ➡️ Initially, this very limited supply of vaccines will go to a small number of hospitals to vaccinate health care workers at high risk of exposure to COVID-19 – those who are caring for or cleaning areas used by patients with COVID-19.\n\n(1/2)
# 2229                                                                                                                                                                                                                                                          THESE EXPERTS DONT KNOW ABOUT LONG TERM SIDE EFFECTS OF OF THIS COVID VACCINE, AND KNOW YOUR AT HIGH RISK OF GETTING MYELITIS
# 2799                                                                              Moderna is filing for regulatory approval in the US and EU as its vaccine is now 94% efficient.\nWhat could happen to major indices as a result?\nTrading on margin is high risk. Losses can exceed deposits. \n#vaccinenews #covidvaccine #financialmarkets #broker #tradingnews https://t.co/premUVEB0h
# 3031                                                                                                       Don’t see Obstetrics being advocated for as 1st to get vaccine. Pregnant women are high risk. +Obstetricians labor and perform C-sections routinely on CoVid positive patients. I know I have many times. We are frontline in this pandemic too🤷🏽‍♀️..but I’m bias #CovidVaccine
#                                                                                                                                                                                                  ...
# 1079353                                                                                                                                                                                         I saw that obesity puts you in the high risk category for covid. Hopefully that means I’ll be closer to the front of the vaccine line.\n\nShout out to racism, fatphobia, and the BMI chart
# 1079405                                                                                          @CNN Let the individual person decide if they need the Vaccine first.  While my spouse and I are in the over 65 1B high risk group we are able to control ourselves and limit our risk and exposure. We do not want to stop someone who believes they are in danger from getting COVID-19.
# 1079516                                                                                            You have a higher risk, 2.79%, of having adverse reactions to the vaccine than from dying of #COVID, 1.8% risk (this includes elderly, high risk). If you’re a healthy adult, ages 18-40, risk of vaccine injury vs death from the virus is much higher. @CDCgov https://t.co/I2ajQNvjwB
# 1080229                                                                                   Intentional. Someone at a medical center deliberately destroyed 500 doses of Covid vaccine. Those doses were 500 unprotected nurses, doctors, emergency workers, elderly people, high risk people. Bc of one person LARPing as a resistance fighter against evil science. https://t.co/Ci4KQFcuk6
# 1080518                                                                        @repjacoby 1) He’s very high risk\n\n2) He’s a senator. While I don’t think they should be, government leaders are being prioritized\n\n3) It’s recommended to get the vaccine even if you’ve had COVID\n\nTrump &amp; many Republican leaders screwed up so much when it comes to COVID, but this isn’t one
# Name: Text, Length: 2093, dtype: object

# %%
input_ = 'Positive'
pos = BigramsAnalysis(input_)

# %%
pos
# Out:
#                         bigram  count
# 0               (health, care)   9892
# 1                 (next, week)   8230
# 2              (care, workers)   6140
# 3   (approves, pfizerbiontech)   5116
# 4              (approved, use)   5079
# 5              (side, effects)   5038
# 6                    (let, us)   4859
# 7               (uk, approves)   4828
# 8             (emergency, use)   4126
# 9                    (use, uk)   3833
# 10               (first, dose)   3719
# 11            (united, states)   3714
# 12           (safe, effective)   3686
# 13       (healthcare, workers)   3667
# 14               (need, worry)   3514
# 15            (health, canada)   3470
# 16                 (new, york)   3232
# 17               (warp, speed)   2764
# 18            (longterm, care)   2726
# 19                (get, first)   2719
# 20                (good, news)   2644
# 21                (long, term)   2639
# 22             (bush, clinton)   2635
# 23               (obama, bush)   2609
# 24             (public, trust)   2542
# 25           (get, vaccinated)   2537
# 26                 (bbc, news)   2508
# 27              (among, first)   2494
# 28            (first, receive)   2434
# 29              (could, begin)   2434
# 30            (public, health)   2377
# 31            (take, publicly)   2339
# 32                  (I, would)   2318
# 33                 (say, take)   2309
# 34       (begin, vaccinations)   2309
# 35        (vaccinations, next)   2294
# 36            (million, doses)   2293
# 37              (clinton, say)   2277
# 38              (gain, public)   2240
# 39            (publicly, gain)   2212
# 40               (front, line)   2204
# 41          (pfizer, biontech)   2181
# 42            (immune, system)   2172
# 43            (critical, care)   2151
# 44                (wear, mask)   2124
# 45             (first, person)   2124
# 46              (first, doses)   2087
# 47               (people, get)   2006
# 48           (operation, warp)   1967
# 49           (tests, positive)   1964
