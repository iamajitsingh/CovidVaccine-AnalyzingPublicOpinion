# %%
  # Import PyDrive and associated libraries
# This only needs to be done once per notebook
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client
# This only needs to be done once per notebook
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Download a file based on its file ID.

# A file ID looks like: laggVyWshwcyP6kEI-y_W3P8D26sz
file_id = '1izAYScZGiWfis_xXRoGwqgFlhCsPeu5R' # Check your own ID in GDrive
downloaded = drive.CreateFile({'id': file_id})

# Save file in Colab memory
downloaded.GetContentFile('tweet_data.csv')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
import seaborn as sns
sns.set_style('dark')
from wordcloud import WordCloud
from textblob import TextBlob

# %%
df = pd.read_csv('tweet_data.csv', lineterminator='\n')
df = df.drop(['Unnamed: 0'],axis=1)

# %%
# Performing VADER Sentiment Analysis
import nltk
nltk.download('vader_lexicon') # Download the VADER lexicon
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Initialize sentiment intensity analyzer
sia = SentimentIntensityAnalyzer()

# Obtaining NLTK scores
df['VScore'] = df['Clean Text'].apply(lambda x: sia.polarity_scores(x))

# Obtaining NLTK compound score
df['VComp'] = df['VScore'].apply(lambda score_dict: score_dict['compound'])

# Set threshold to define neutral sentiment
neutral_thresh = 0.05

# Categorize scores into the sentiments of positive, neutral or negative
df['Sentiment'] = df['VComp'].apply(lambda c: 'Positive' if c >= neutral_thresh else ('Negative' if c <= -(neutral_thresh) else 'Neutral'))
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# # Ngrams Analysis

# %%
import networkx as nx
import itertools, collections
from nltk import bigrams
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
new_stopwords_to_add = ['covid19', 'covid','vaccine', 'covid-19', '19', 'vaccines', 'vaccine.','vaccine?', '-', '.']
stop_words.extend(new_stopwords_to_add)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Check d[0].items() for understanding more about graph plot

def BigramsAnalysis(sentiment):
  l_words = df[df["Sentiment"]==sentiment]["Clean Text"].tolist()
  words_in_tweet = [tweet.split() for tweet in l_words]
  words_lemmatized = [[word for word in tweet_words]
              for tweet_words in words_in_tweet]
  tweets_nsw = [[word for word in tweet_words if not word in stop_words]
              for tweet_words in words_lemmatized]
  terms_bigram = [list(bigrams(tweet)) for tweet in tweets_nsw if tweet]
  bigrams_list = list(itertools.chain(*terms_bigram))
  bigram_counts = collections.Counter(bigrams_list)
  bigram_df = pd.DataFrame(bigram_counts.most_common(50),
                             columns=['bigram', 'count'])
  d = bigram_df.set_index('bigram').T.to_dict('records')
  G = nx.Graph()
  for k, v in d[0].items():
    G.add_edge(k[0], k[1], weight=(v))
  fig, ax = plt.subplots(figsize=(14, 10))

  pos = nx.spring_layout(G, k=2)

  # Plot networks
  nx.draw_networkx(G, pos,
                  font_size=16,
                  width=3,
                  edge_color='grey',
                  node_color='purple',
                  with_labels = False,
                  ax=ax)

  # Create offset labels
  for key, value in pos.items():
      x, y = value[0]+.100, value[1]+.025
      ax.text(x, y,
              s=key,
              bbox=dict(facecolor='red', alpha=0.15),
              horizontalalignment='center', fontsize=13)
      
  plt.show()
  return bigram_df

def Search(keywords):
  pd.set_option('display.max_colwidth', 400)
  result = df[df["Clean Text"].str.contains(keywords)]["Text"]
  return result

# %% [markdown]
# # Testing Analysis on data

# %%
input_ = 'Negative'
neg = BigramsAnalysis(input_)

# %%
neg
# Out:
#                     bigram  count
# 0          (side, effects)   9049
# 1        (get, vaccinated)   6343
# 2           (people, died)   5297
# 3             (long, term)   5205
# 4             (still, get)   4513
# 5              (flu, shot)   4362
# 6      (fully, vaccinated)   4219
# 7     (vaccinated, people)   4168
# 8           (many, people)   3734
# 9            (people, get)   3681
# 10        (delta, variant)   3209
# 11               (let, us)   3033
# 12     (natural, immunity)   3010
# 13             (get, sick)   2704
# 14            (last, year)   2429
# 15        (negative, test)   2408
# 16           (people, die)   2349
# 17         (people, still)   2335
# 18         (people, dying)   2183
# 19  (unvaccinated, people)   2176
# 20             (new, york)   2175
# 21        (booster, shots)   2143
# 22              (I, would)   2121
# 23          (less, likely)   2117
# 24        (immune, system)   2023
# 25        (public, health)   2014
# 26            (wear, mask)   2008
# 27       (people, getting)   1966
# 28              (get, flu)   1956
# 29    (adverse, reactions)   1896
# 30           (death, rate)   1888
# 31         (term, effects)   1841
# 32            (high, risk)   1748
# 33           (likely, die)   1683
# 34        (mask, mandates)   1679
# 35      (serious, illness)   1670
# 36         (getting, sick)   1653
# 37           (cannot, get)   1639
# 38       (killing, people)   1609
# 39       (severe, illness)   1596
# 40          (stop, spread)   1578
# 41          (blood, clots)   1553
# 42   (getting, vaccinated)   1533
# 43          (nicki, minaj)   1494
# 44             (want, get)   1486
# 45         (times, likely)   1474
# 46         (would, rather)   1436
# 47   (healthcare, workers)   1424
# 48          (side, effect)   1412
# 49     (vaccinated, still)   1395

# %%
Search("let us")
# Out:
# 295                                           (2/4) Vaccines are working 💉\n\nGo back in time for a second. ⏳\n\nLet's remember that the vaccines were created for the Alpha variant to prevent you from becoming severely sick.\n\nIf the virus was a superhero, Alpha would be the Clark Kent version of COVID-19.
# 319                                                   Let us all unite in the fight against #COVID19. It is only when we fight together will we see a better tomorrow! Don't forget to continue taking all necessary precautions even after vaccination!\n#CovidVaccine \n#TogetherWeRecover https://t.co/05cUgZzbge
# 367                          @reddboneash218 @6abc Which variant exactly are the vaccines unsuccessful in preventing SEVERE ILLNESS? Let’s not forget nobody claimed the vaccine will prevent Covid it prevents people from becoming severely ill and reduces transmissibility! Those are the facts Fox don’t report
# 947                              Most unjabbed feel deep sympathy for the jabbed, and hope for an antidote. Dr. Judy says it's suramin: https://t.co/BZb1P5PHSH. BTW, let's all stop calling the 'covid' shots vaccines, because they are not. Poison-death jabs, jabs, shots, #clotshots, injections, not vaccines.
# 993                                                                                                                                            I’m glad the NFL is taking covid vaccines seriously and possibly cutting players who won’t get it. Let’s keep it going for domestic abuse and sexual harassment next!
#                                                                                                                                                              ...
# 920516     @meganranney 💯 going to vaccinate my kids! \n\nIF they didn’t get vaccine in the COVID-19 vaccine trials they are enrolled in!\n\nVaccinating kids will be key in helping manage the pandemic.\nAt least 50 million kids under 12 = 15% total US population - none of them vaccinated. \n\nLet’s do this!
# 920796                                                                                                          @JoyTaylorTalks @KendrickPerkins Let’s just continue to ignore the fact you can still catch and pass the virus with the vaccine… everyone talkin like the vaxx gonna completely save you from covid.
# 920901                                                                                                         Lets see how many i can lose😊\nBojo is a lying deceitful cnt\nFck covid passports\nFck the fake vaccine\nFck this whole scam\nFck the great reset\nMsm is the real virus 🖕\nNo jab for me..... ever 🙏
# 920920    It's not too late to sign up to receive a Covid vaccination tomorrow or on the 22nd. Let's keep our community safe! We are proud to host this vaccine clinic at Cristo Rey Boston. All community members of Dorchester are welcome. https://t.co/I3WpRb53tj\n#WeAreCRB #Dorchester https://t.co/qZCIquB0zl
# 921154                                                                                                 @bceyre22 @VoteJoe1 @__carson @JoJoFromJerz @marcorubio Letting 15,000 people into the country without vaccines or being tested makes my blood boil!!!! Lets end covid by not letting undocumented people in.
# Name: Text, Length: 7184, dtype: object

# %%
input_ = 'Positive'
pos = BigramsAnalysis(input_)

# %%
pos
# Out:
#                           bigram  count
# 0            (natural, immunity)  11248
# 1              (get, vaccinated)   6972
# 2                (side, effects)   5053
# 3              (safe, effective)   4605
# 4            (fully, vaccinated)   3877
# 5               (immune, system)   3838
# 6                      (let, us)   3440
# 7                   (long, term)   3393
# 8                   (still, get)   3235
# 9                 (health, care)   3226
# 10          (vaccinated, people)   2979
# 11                 (people, get)   2961
# 12              (delta, variant)   2734
# 13              (booster, shots)   2610
# 14                (pfizer, says)   2453
# 15               (fda, approved)   2347
# 16                    (I, would)   2264
# 17                       (5, 11)   2199
# 18              (public, health)   2084
# 19           (slots, covishield)   2032
# 20               (booster, shot)   2011
# 21              (united, states)   1979
# 22            (immune, response)   1953
# 23            (tested, positive)   1880
# 24                (many, people)   1769
# 25         (getting, vaccinated)   1755
# 26                 (paid, slots)   1748
# 27                 (free, slots)   1746
# 28     (bengaluru, covidvaccine)   1744
# 29  (covidvaccine, availability)   1744
# 30                  (wear, mask)   1733
# 31                 (save, lives)   1675
# 32                (stop, spread)   1668
# 33               (care, workers)   1661
# 34                   (flu, shot)   1649
# 35                (second, dose)   1633
# 36               (stop, getting)   1621
# 37                     (ages, 5)   1529
# 38               (people, still)   1516
# 39                  (last, year)   1508
# 40                 (first, dose)   1498
# 41               (fda, approval)   1437
# 42                    (us, safe)   1430
# 43                    (slots, 0)   1395
# 44                 (would, like)   1379
# 45                     (I, sure)   1366
# 46       (effective, preventing)   1356
# 47             (people, getting)   1352
# 48                    (none, us)   1332
# 49                   (get, shot)   1315
